# %%
from datasets import load_dataset


dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()
df.head()
# Out:
# ...
# Generating train split: 100%|██████████| 785741/785741 [00:04<00:00, 160978.53 examples/s]
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
# ...

# %%
import pandas as pd
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
df["job_title_short"].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df.groupby("job_title_short")["salary_year_avg"].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby("job_title_short")[["salary_year_avg", "salary_hour_avg"]].min()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                   16500.0           10.835
# Cloud Engineer                     42000.0           18.500
# Data Analyst                       25000.0            8.000
# Data Engineer                      15000.0            8.000
# Data Scientist                     27000.0            8.000
# Machine Learning Engineer          30000.0           10.000
# Senior Data Analyst                30000.0           13.000
# Senior Data Engineer               35000.0           12.500
# Senior Data Scientist              45000.0           17.500
# Software Engineer                  28000.0           11.000

# %%
df.groupby("job_title_short")["salary_year_avg"].agg(["min","max"])
# Out:
#                                min       max
# job_title_short
# Business Analyst           16500.0  387460.0
# Cloud Engineer             42000.0  280000.0
# Data Analyst               25000.0  650000.0
# Data Engineer              15000.0  525000.0
# Data Scientist             27000.0  960000.0
# Machine Learning Engineer  30000.0  325000.0
# Senior Data Analyst        30000.0  425000.0
# Senior Data Engineer       35000.0  425000.0
# Senior Data Scientist      45000.0  890000.0
# Software Engineer          28000.0  375000.0

# %%
df["job_country"].isin(["Turkey"]).any()
# Out:
# np.True_

# %%
tr_jobs= df[df["job_country"] == "Turkey"]
tr_jobs
# Out:
#              job_title_short  \
# 242           Data Scientist
# 1256    Senior Data Engineer
# 1560           Data Engineer
# 1917       Software Engineer
# 2901          Data Scientist
# ...                      ...
# 783975         Data Engineer
# 784245         Data Engineer
# 785250          Data Analyst
# 785420         Data Engineer
# 785571          Data Analyst
#
#                                                 job_title  \
# 242                                        Data Scientist
# 1256                                 Senior Data Engineer
# 1560                         Data Engineer & BI Developer
# 1917                           Software Engineer - Python
# 2901                                       Data Scientist
# ...                                                   ...
# 783975                                      Data Engineer
# 784245                                      Data Engineer
# 785250                                       Data Analyst
# ...

# %%
tr_jobs = tr_jobs[tr_jobs["salary_year_avg"].notna()]

# %%
tr_jobs.groupby("job_title_short")["salary_year_avg"].agg(["median","min","max","count"]).sort_values(by="median",ascending=False)
# Out:
#                         median      min       max  count
# job_title_short
# Senior Data Analyst    98500.0  98500.0   98500.0      1
# Data Engineer          97528.0  79200.0  147500.0      4
# Senior Data Scientist  76464.0  64800.0   88128.0      2
# Data Scientist         75600.0  47370.0   88128.0      6
# Software Engineer      64800.0  37500.0   87500.0      3
# Data Analyst           57600.0  50400.0  163782.0      5
